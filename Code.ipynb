# %%
# Imports of Important Library
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# Cleaning Data

# df = pd.read_csv("data/content.csv")
# condition = (df["language"]=='en')
# filtered_df = df[condition]
# filtered_df.to_csv('data/flitered_df.csv', index=False)

# %%
df = pd.read_csv("data/filtered_df.csv")

# %%
df
# Out:
#                    id                                              title  \
# 0      c_00019840d110              5.12E: Regulation of the Calvin Cycle
# 1      c_00027d03ca7d           4.E: Genomes and Chromosomes (Exercises)
# 2      c_000425df0161            9.3: Van Der Waals Forces between Atoms
# 3      c_00046806ad8a                        Compare multi-digit numbers
# 4      c_000751f58836            Tangents of circles problem (example 2)
# ...               ...                                                ...
# 65934  c_fffa90b024e3                   Congruent Triangle Proof Example
# 65935  c_fffbfc3d60c6  number_lines_mixed_positive_student writes num...
# 65936  c_fffcbdd4de8b                                   2. 12: Diffusion
# 65937  c_ffff04ba7ac7                                       SA of a Cone
# 65938  c_ffffe5254266                                           The Jats
#
#                                              description      kind  \
# ...

# %%
fig = px.histogram(df, x="kind", title="Types of Data", labels={"kind":"Type of Data"}, color="kind")
fig.show()

# %%
fig = px.histogram(df, x="license", title="License Type", labels={"license":"Type of License"},color="license")
fig.show()

# %%
# Check for null elements in the title column.
df["title"].isnull().sum()
# Out:
# 0
